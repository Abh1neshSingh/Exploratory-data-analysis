# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/Users/abhineshsingh/Music/EDA DATA/heart_failure_clinical_records_dataset.csv")

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df.shape
# Out:
# (299, 13)

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
df.tail()
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 294                    1   155000.0               1.1           143    1
# 295                    0   270000.0               1.2           139    0
# 296                    0   742000.0               0.8           138    0
# 297                    0   140000.0               1.4           140    1
# 298                    0   395000.0               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 294        1   270            0
# ...

# %%
df.sample(5)
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 128  61.0        0                       248         0                 30
# 221  65.0        0                       118         0                 50
# 235  77.0        1                       109         0                 50
# 176  69.0        0                      1419         0                 40
# 223  47.0        0                       582         0                 25
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 128                    1   267000.0               0.7           136    1
# 221                    0   194000.0               1.1           145    1
# 235                    1   406000.0               1.1           137    1
# 176                    0   105000.0               1.0           135    1
# 223                    0   130000.0               0.8           134    1
#
#      smoking  time  DEATH_EVENT
# 128        1   104            0
# ...

# %%
df.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# What is the distribution of age among heart failure patients in the dataset

# %%
df['age'].describe()
# Out:
# count    299.000000
# mean      60.833893
# std       11.894809
# min       40.000000
# 25%       51.000000
# 50%       60.000000
# 75%       70.000000
# max       95.000000
# Name: age, dtype: float64

# %%
#----> Insights 
# Count: There are 299 records in the dataset, indicating that there are 299 heart failure patients whose ages are recorded.

# Mean: The average age of heart failure patients in the dataset is approximately 60.83 years. This suggests that the dataset is centered around this age.

# Standard Deviation: The standard deviation of approximately 11.89 indicates the spread or dispersion of ages around the mean. A higher standard deviation suggests more variability in ages among patients.

# Minimum and Maximum: The minimum recorded age is 40 years, while the maximum recorded age is 95 years. This shows the range of ages covered in the dataset.

# Quartiles (25th, 50th, and 75th percentiles):

#  25th percentile (Q1): 25% of the patients are aged 51 years or younger.
#  50th percentile (Median): 50% of the patients are aged 60 years or younger.
#  75th percentile (Q3): 75% of the patients are aged 70 years or younger.

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['age'], bins=20, edgecolor='black', alpha=0.7)
plt.title('Histogram of Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
df.anaemia.value_counts()
# Out:
# anaemia
# 0    170
# 1    129
# Name: count, dtype: int64

# %%
# Ages with anaemia cases for  heart failure patients
df.groupby('anaemia')['age'].describe()
# Out:
#          count       mean        std   min   25%   50%   75%   max
# anaemia
# 0        170.0  59.923529  11.906441  40.0  50.0  60.0  70.0  94.0
# 1        129.0  62.033597  11.818421  40.0  53.0  60.0  68.0  95.0

# %%
anaemia_counts = df['anaemia'].value_counts()

# Create a bar plot
plt.figure(figsize=(6, 4))
plt.bar(['No Anaemia--0', 'Anaemia--1'], anaemia_counts, color=['skyblue', 'salmon'])
plt.title('Distribution of Anaemia Among Patients')
plt.xlabel('Anaemia')
plt.ylabel('Count')
plt.show()

# %%
df.diabetes.value_counts()
# Out:
# diabetes
# 0    174
# 1    125
# Name: count, dtype: int64

# %%
# Ages with diabetes cases for heart failure patients
df.groupby('diabetes')['age'].describe()
# Out:
#           count       mean        std   min   25%   50%   75%   max
# diabetes
# 0         174.0  61.850575  12.721134  40.0  52.0  60.0  70.0  95.0
# 1         125.0  59.418672  10.525180  40.0  50.0  60.0  65.0  94.0

# %%
age_stats_by_diabetes = df.groupby('diabetes')['age'].describe()


age_stats_by_diabetes.plot(kind='bar', figsize=(10, 6))
plt.title('Summary Statistics of Age by Diabetes')
plt.xlabel('Diabetes')
plt.ylabel('Value')
plt.xticks(rotation=0)
plt.legend(title='Diabetes', labels=['Non-Diabetic', 'Diabetic'])
plt.grid(axis='y')
plt.show()

# %%
df.sex.value_counts()
# Out:
# sex
# 1    194
# 0    105
# Name: count, dtype: int64

# %%
# Ages in each gender
df.groupby('sex')['age'].describe()
# Out:
#      count       mean        std   min   25%   50%   75%   max
# sex
# 0    105.0  59.777781  11.240919  40.0  50.0  60.0  66.0  95.0
# 1    194.0  61.405500  12.224415  40.0  52.0  60.0  70.0  95.0

# %%
age_stats_by_sex = df.groupby('sex')['age'].describe()

# Plot bar plot
age_stats_by_sex.plot(kind='bar', figsize=(10, 6))
plt.title('Summary Statistics of Age by Sex')
plt.xlabel('Sex')
plt.ylabel('Value')
plt.xticks(rotation=0)
plt.legend(title='Sex', labels=['Female', 'Male'])
plt.grid(axis='y')
plt.show()

# %%
df.smoking.value_counts()
# Out:
# smoking
# 0    203
# 1     96
# Name: count, dtype: int64

# %%
# Ages with smoking cases
df.groupby('smoking')['age'].describe()
# Out:
#          count       mean        std   min   25%   50%   75%   max
# smoking
# 0        203.0  60.681448  12.157714  40.0  50.0  60.0  68.5  95.0
# 1         96.0  61.156250  11.374328  40.0  52.0  60.0  70.0  90.0

# %%
age_stats_by_smoking = df.groupby('smoking')['age'].describe()

# Plot bar plot
age_stats_by_smoking.plot(kind='bar', figsize=(10, 6))
plt.title('Summary Statistics of Age by Smoking')
plt.xlabel('Smoking')
plt.ylabel('Value')
plt.xticks(rotation=0)
plt.legend(title='Smoking', labels=['Non-Smoker', 'Smoker'])
plt.grid(axis='y')
plt.show()

# %%
# age corr
plt.figure(figsize=(15, 10))
sns.heatmap(df.loc[:, ['age', 'anaemia', 'diabetes', 'high_blood_pressure', 'smoking']].corr(), annot=True)
plt.title('Correlation between age and anaemia, diabetes, high blood pressure and smoking')
plt.show()

# %%
# How does the death rate vary with age

# %%
df['DEATH_EVENT'].value_counts()
# Out:
# DEATH_EVENT
# 0    203
# 1     96
# Name: count, dtype: int64

# %%
df.groupby('DEATH_EVENT')['age'].describe()
# Out:
#              count       mean        std   min   25%   50%   75%   max
# DEATH_EVENT
# 0            203.0  58.761906  10.637890  40.0  50.0  60.0  65.0  90.0
# 1             96.0  65.215281  13.214556  42.0  55.0  65.0  75.0  95.0

# %%
plt.figure(figsize=(10, 7))
death_age = df.groupby('DEATH_EVENT')['age'].mean()
plt.pie(death_age, autopct='%.1f%%', labels=['Alive', 'Dead'], explode=[0.1, 0], shadow=True)
plt.title('Average Ages In Death Cases')
plt.legend(death_age, loc='upper right')
plt.show()

# %%
death_age = df.groupby('DEATH_EVENT')['age'].mean()


plt.figure(figsize=(10, 7))
death_age.plot(kind='bar', color=['green', 'red'], alpha=0.7)
plt.title('Average Age in Death Cases')
plt.xlabel('Death Event')
plt.ylabel('Average Age')
plt.xticks([0, 1], ['Alive', 'Dead'], rotation=0)
plt.grid(axis='y')
plt.show()

# %%
df.groupby('DEATH_EVENT')['anaemia'].value_counts()
# Out:
# DEATH_EVENT  anaemia
# 0            0          120
#              1           83
# 1            0           50
#              1           46
# Name: count, dtype: int64

# %%
death_anae = df.groupby(['DEATH_EVENT', 'anaemia']).size().unstack()

# Plot bar plot
plt.figure(figsize=(10, 7))
death_anae.plot(kind='bar', stacked=True, color=['lightgreen', 'lightcoral'], alpha=0.7)
plt.title('Anaemic Patients In Death Cases')
plt.xlabel('Death Event')
plt.ylabel('Count')
plt.xticks([0, 1], ['Alive', 'Dead'], rotation=0)
plt.legend(['Non-Anaemic', 'Anaemic'], loc='upper left')
plt.grid(axis='y')
plt.show()

# %%
death_anae = df.groupby(['DEATH_EVENT', 'anaemia']).size().unstack()
labels = ['Alive-non anaemic', 'Alive-anaemic', 'Dead-non anaemic', 'Dead-anaemic']
values = death_anae.values.flatten()
colors = ['#66c2a5', '#8da0cb', '#fc8d62', '#e78ac3']
myexplode = [0.1, 0, 0.1, 0]
plt.figure(figsize=(10, 7))
plt.pie(values, autopct='%.1f%%', labels=labels, explode=myexplode, colors=colors, shadow=True)
plt.title('Anaemic Patients In Death Cases')
plt.show()

# %%
# Patients of death and diabetes cases
df.groupby('DEATH_EVENT')['diabetes'].value_counts()
# Out:
# DEATH_EVENT  diabetes
# 0            0           118
#              1            85
# 1            0            56
#              1            40
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 7))
death_diab = df.groupby('DEATH_EVENT')['diabetes'].value_counts()
myexplode = [0.1, 0, 0.2, 0]
plt.pie(death_diab, autopct='%.1f%%', labels=['Alive-non diabetic', 'Alive-diabetic', 'Dead-non diabetic', 'Dead-diabetic'], explode=myexplode, shadow=True)
plt.title('Diabetic Patients In Death Cases')
plt.legend(death_diab, loc='upper left')
plt.show()

# %%
# Patients of death and hypertension cases
df.groupby('DEATH_EVENT')['high_blood_pressure'].value_counts()
# Out:
# DEATH_EVENT  high_blood_pressure
# 0            0                      137
#              1                       66
# 1            0                       57
#              1                       39
# Name: count, dtype: int64

# %%
# Group by 'DEATH_EVENT' and 'high_blood_pressure' and compute value counts
death_hbp = df.groupby(['DEATH_EVENT', 'high_blood_pressure']).size().unstack()

# Plot bar plot
plt.figure(figsize=(10, 7))
death_hbp.plot(kind='bar', stacked=True, color=['lightblue', 'salmon'], alpha=0.7)
plt.title('Blood Pressure Patients In Death Cases')
plt.xlabel('Death Event')
plt.ylabel('Count')
plt.xticks([0, 1], ['Alive', 'Dead'], rotation=0)
plt.legend(['Normal Pressure', 'High Pressure'], loc='upper left')
plt.grid(axis='y')
plt.show()

# %%
# Patients of death and smoking cases
df.groupby('DEATH_EVENT')['smoking'].value_counts()
# Out:
# DEATH_EVENT  smoking
# 0            0          137
#              1           66
# 1            0           66
#              1           30
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 7))
death_smok = df.groupby('DEATH_EVENT')['smoking'].value_counts()
myexplode = [0.1, 0, 0.2, 0]
plt.pie(death_smok, autopct='%.1f%%', labels=['Alive-non smoker', 'Alive-smoker', 'Dead-non smoker', 'Dead-smoker'], explode=myexplode, shadow=True)
plt.title('Smoker Patients In Death Cases')
plt.legend(death_smok, loc='upper left')
plt.show()

# %%
plt.figure(figsize=(20, 15))
sns.heatmap(df.corr(), annot=True)
plt.title('Correlation between Death Events and other data')
plt.show()

# %%
# What is the percentage of male and female patients in the dataset?

# %%
df['sex']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 294    1
# 295    0
# 296    0
# 297    1
# 298    1
# Name: sex, Length: 299, dtype: int64

# %%
df['sex'].unique()
# Out:
# array([1, 0])

# %%
df['sex'] = df['sex'].replace({1: 'Male', 0: 'Female'})
gender_percentage = df['sex'].value_counts(normalize=True) * 100
gender_percentage = gender_percentage.round(2)
print("Percentage of Male patients:", gender_percentage['Male'])
print("Percentage of Female patients:", gender_percentage['Female'])
# Out:
# Percentage of Male patients: 64.88
# Percentage of Female patients: 35.12

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
#how does the platelet count vary among different age groups?

# %%
df['age']
# Out:
# 0      75.0
# 1      55.0
# 2      65.0
# 3      50.0
# 4      65.0
#        ...
# 294    62.0
# 295    55.0
# 296    45.0
# 297    45.0
# 298    50.0
# Name: age, Length: 299, dtype: float64

# %%
df['platelets']
# Out:
# 0      265000.00
# 1      263358.03
# 2      162000.00
# 3      210000.00
# 4      327000.00
#          ...
# 294    155000.00
# 295    270000.00
# 296    742000.00
# 297    140000.00
# 298    395000.00
# Name: platelets, Length: 299, dtype: float64

# %%
platelets_description = df['platelets'].describe()

# %%
platelets_description
# Out:
# count       299.000000
# mean     263358.029264
# std       97804.236869
# min       25100.000000
# 25%      212500.000000
# 50%      262000.000000
# 75%      303500.000000
# max      850000.000000
# Name: platelets, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='platelets', data=df, alpha=0.5)
plt.title('Platelet Count vs Age')
plt.xlabel('Age')
plt.ylabel('Platelet Count')
plt.grid(True)
plt.show()

# %%
# is there a correction between creatinine and sodium level  in the blood?

# %%
df['serum_creatinine']
# Out:
# 0      1.9
# 1      1.1
# 2      1.3
# 3      1.9
# 4      2.7
#       ...
# 294    1.1
# 295    1.2
# 296    0.8
# 297    1.4
# 298    1.6
# Name: serum_creatinine, Length: 299, dtype: float64

# %%
df['serum_sodium']
# Out:
# 0      130
# 1      136
# 2      129
# 3      137
# 4      116
#       ...
# 294    143
# 295    139
# 296    138
# 297    140
# 298    136
# Name: serum_sodium, Length: 299, dtype: int64

# %%
correlation_matrix = df[['serum_creatinine', 'serum_sodium']].corr()

# Plotting the heatmap
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap between Serum Creatinine and Serum Sodium')
plt.show()

# %%
# how does the prevalence of high blood pressure differ between male and female patients

# %%
df['high_blood_pressure'].unique()
# Out:
# array([1, 0])

# %%
# Replace 
df['sex'] = df['sex'].replace({1: 'Male', 0: 'Female'})
df['high_blood_pressure'] = df['high_blood_pressure'].replace({1: 'Yes', 0: 'No'})
high_bp_percentage_by_gender = df.groupby('sex')['high_blood_pressure'].value_counts(normalize=True) * 100
print("Prevalence of High Blood Pressure:")
print(high_bp_percentage_by_gender)
# Out:
# Prevalence of High Blood Pressure:
# sex     high_blood_pressure
# Female  No                     58.095238
#         Yes                    41.904762
# Male    No                     68.556701
#         Yes                    31.443299
# Name: proportion, dtype: float64

# %%
df['sex'] = df['sex'].replace({1: 'Male', 0: 'Female'})
df['high_blood_pressure'] = df['high_blood_pressure'].replace({1: 'Yes', 0: 'No'})

high_bp_percentage_by_gender = df.groupby('sex')['high_blood_pressure'].value_counts(normalize=True) * 100

plt.figure(figsize=(8, 6))
high_bp_percentage_by_gender.unstack().plot(kind='bar', color=['skyblue', 'salmon'], alpha=0.7)
plt.title('Prevalence of High Blood Pressure by Gender')
plt.xlabel('Gender')
plt.ylabel('Percentage')
plt.xticks(rotation=0)
plt.legend(title='High Blood Pressure', labels=['No', 'Yes'])
plt.grid(axis='y')
plt.show()

# %%
#what is the relationship between smoking habits and the occurrence of heart failure?

# %%
df['smoking']
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 294    1
# 295    0
# 296    0
# 297    1
# 298    1
# Name: smoking, Length: 299, dtype: int64

# %%
df['smoking'].value_counts()
# Out:
# smoking
# 0    203
# 1     96
# Name: count, dtype: int64

# %%
df['smoking'] = df['smoking'].replace({0: 'Non-Smoker', 1: 'Smoker'})
smoking_counts = df.groupby('smoking')['DEATH_EVENT'].value_counts().unstack().fillna(0)

plt.figure(figsize=(8, 6))
smoking_counts.plot(kind='bar', stacked=True, color=['lightblue', 'salmon'], alpha=0.7)
plt.title('Heart Failure Cases Among Smokers and Non-Smokers')
plt.xlabel('Smoking Status')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Heart Failure', labels=['No', 'Yes'])
plt.grid(axis='y')
plt.show()

# %%
# are there any noticeable patterns in the distribution of death event across different age groups

# %%
df['DEATH_EVENT']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 294    0
# 295    0
# 296    0
# 297    0
# 298    0
# Name: DEATH_EVENT, Length: 299, dtype: int64

# %%
plt.figure(figsize=(10, 7))
plt.scatter(df['age'], df['DEATH_EVENT'], color='blue', alpha=0.5)
plt.title('pattern of death event across different age groups ')
plt.xlabel('Age')
plt.ylabel('Death Event')
plt.yticks([0, 1], ['No', 'Yes'])
plt.grid(True)
plt.show()

# %%
# is there any significant difference in ejection fraction between 
# patient with and without diabetes ?

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='diabetes', y='ejection_fraction', data=df, palette='Set2')
plt.title('Ejection Fraction Comparison Between Patients with and without Diabetes')
plt.xlabel('Diabetes')
plt.ylabel('Ejection Fraction')
plt.xticks([0, 1], ['No Diabetes', 'Diabetes'])
plt.grid(axis='y')
plt.show()

# %%
#  How does the serum creatine level vary between patient who
#   survived and those who did not

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='DEATH_EVENT', y='serum_creatinine', data=df, palette='Set2')
plt.title('Serum Creatinine Level Comparison between Survived and Not Survived Patients')
plt.xlabel('Death Event')
plt.ylabel('Serum Creatinine Level')
plt.xticks([0, 1], ['Survived', 'Not Survived'])
plt.grid(axis='y')
plt.show()
