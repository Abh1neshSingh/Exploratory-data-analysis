# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

import warnings 
warnings.filterwarnings('ignore')

plt.style.use("fivethirtyeight")
# %matplotlib inline

pd.set_option('display.max_columns',30)

# %%
df=pd.read_csv("/Users/abhineshsingh/Music/EDA DATA/us_perm_visas.csv")

# %%
df
# Out:
#        add_these_pw_job_title_9089   agent_city  \
# 0                              NaN          NaN
# 1                              NaN          NaN
# 2                              NaN          NaN
# 3                              NaN          NaN
# 4                              NaN          NaN
# ...                            ...          ...
# 374357                         NaN   Buena Park
# 374358                         NaN      Seattle
# 374359                         NaN   Schaumburg
# 374360                         NaN  LOS ANGELES
# 374361                         NaN      Phoenix
#
#                                           agent_firm_name agent_state  \
# 0                                                     NaN         NaN
# 1                                                     NaN         NaN
# 2                                                     NaN         NaN
# 3                                                     NaN         NaN
# ...

# %%
df.columns
# Out:
# Index(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_no', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        ...
#        'ri_pvt_employment_firm_to', 'ri_us_workers_considered',
#        'schd_a_sheepherder', 'us_economic_sector', 'wage_offer_from_9089',
#        'wage_offer_to_9089', 'wage_offer_unit_of_pay_9089',
#        'wage_offered_from_9089', 'wage_offered_to_9089',
#        'wage_offered_unit_of_pay_9089'],
#       dtype='object', length=154)

# %%
df.shape
# Out:
# (374362, 154)

# %%
df.head()
# Out:
#   add_these_pw_job_title_9089 agent_city agent_firm_name agent_state  \
# 0                         NaN        NaN             NaN         NaN
# 1                         NaN        NaN             NaN         NaN
# 2                         NaN        NaN             NaN         NaN
# 3                         NaN        NaN             NaN         NaN
# 4                         NaN        NaN             NaN         NaN
#
#   application_type        case_no case_number case_received_date case_status  \
# 0             PERM  A-07323-97014         NaN                NaN   Certified
# 1             PERM  A-07332-99439         NaN                NaN      Denied
# 2             PERM  A-07333-99643         NaN                NaN   Certified
# 3             PERM  A-07339-01930         NaN                NaN   Certified
# 4             PERM  A-07345-03565         NaN                NaN   Certified
#
#   class_of_admission country_of_citizenship country_of_citzenship  \
# ...

# %%
df.tail()
# Out:
#        add_these_pw_job_title_9089   agent_city  \
# 374357                         NaN   Buena Park
# 374358                         NaN      Seattle
# 374359                         NaN   Schaumburg
# 374360                         NaN  LOS ANGELES
# 374361                         NaN      Phoenix
#
#                                           agent_firm_name agent_state  \
# 374357                           Law Offices of Yohan Lee          CA
# 374358                         MacDonald Hoague & Bayless          WA
# 374359  International Legal and Business Services Grou...          IL
# 374360                        LAW OFFICES OF JAMES S HONG          CA
# 374361            Fragomen, Del Rey, Bernsen & Loewy, LLP          AZ
#
#        application_type case_no    case_number case_received_date case_status  \
# 374357              NaN     NaN  A-16363-85407         2016-12-29   Withdrawn
# 374358              NaN     NaN  A-16271-56745         2016-12-30   Withdrawn
# ...

# %%
df.sample(4)
# Out:
#        add_these_pw_job_title_9089  agent_city  \
# 69724                          NaN         NaN
# 122918                         NaN         NaN
# 101023                         NaN         NaN
# 236165                         NaN  Glen Allen
#
#                          agent_firm_name agent_state application_type  \
# 69724                                NaN         NaN           ONLINE
# 122918                               NaN         NaN           ONLINE
# 101023                               NaN         NaN           ONLINE
# 236165  Dyer Immigration Law Group, P.C.          VA              NaN
#
#               case_no    case_number case_received_date        case_status  \
# 69724   A-13053-42716            NaN                NaN          Certified
# 122918  A-12269-01962            NaN                NaN  Certified-Expired
# 101023  A-13176-74759            NaN                NaN  Certified-Expired
# ...

# %%
df.isnull().sum()
# Out:
# add_these_pw_job_title_9089      332168
# agent_city                       162908
# agent_firm_name                  167365
# agent_state                      166123
# application_type                 239093
#                                   ...
# wage_offer_to_9089               300728
# wage_offer_unit_of_pay_9089      115916
# wage_offered_from_9089           259715
# wage_offered_to_9089             343347
# wage_offered_unit_of_pay_9089    303663
# Length: 154, dtype: int64

# %%
df.dtypes
# Out:
# add_these_pw_job_title_9089       object
# agent_city                        object
# agent_firm_name                   object
# agent_state                       object
# application_type                  object
#                                   ...
# wage_offer_to_9089                object
# wage_offer_unit_of_pay_9089       object
# wage_offered_from_9089           float64
# wage_offered_to_9089             float64
# wage_offered_unit_of_pay_9089     object
# Length: 154, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374362 entries, 0 to 374361
# Columns: 154 entries, add_these_pw_job_title_9089 to wage_offered_unit_of_pay_9089
# dtypes: float64(10), object(144)
# memory usage: 439.8+ MB

# %%
df.describe()
# Out:
#        employer_num_employees  employer_yr_estab  \
# count            2.390130e+05      238958.000000
# mean             2.309387e+04        1984.208267
# std              5.453129e+05          38.470555
# min              0.000000e+00           0.000000
# 25%              7.300000e+01        1980.000000
# 50%              1.200000e+03        1996.000000
# 75%              1.613400e+04        2004.000000
# max              2.635506e+08        2016.000000
#
#        foreign_worker_yr_rel_edu_completed  fw_info_yr_rel_edu_completed  \
# count                         83364.000000                 137198.000000
# mean                           2001.345761                   2002.633603
# std                              91.444715                     89.674423
# min                               0.000000                      0.000000
# 25%                            2003.000000                   2004.000000
# 50%                            2006.000000                   2007.000000
# ...

# %%
df.describe(include='all')
# Out:
#               add_these_pw_job_title_9089 agent_city  \
# count                               42194     211454
# unique                               4276       1838
# top     Software Developers, Applications   New York
# freq                                10042      19359
# mean                                  NaN        NaN
# std                                   NaN        NaN
# min                                   NaN        NaN
# 25%                                   NaN        NaN
# 50%                                   NaN        NaN
# 75%                                   NaN        NaN
# max                                   NaN        NaN
#
#                                 agent_firm_name agent_state application_type  \
# count                                    206997      208239           135269
# unique                                    10135         108                3
# top     Fragomen, Del Rey, Bernsen & Loewy, LLP          CA           ONLINE
# ...

# %%
df.columns.values
# Out:
# array(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_no', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        'country_of_citizenship', 'country_of_citzenship', 'decision_date',
#        'employer_address_1', 'employer_address_2', 'employer_city',
#        'employer_country', 'employer_decl_info_title', 'employer_name',
#        'employer_num_employees', 'employer_phone', 'employer_phone_ext',
#        'employer_postal_code', 'employer_state', 'employer_yr_estab',
#        'foreign_worker_info_alt_edu_experience',
#        'foreign_worker_info_birth_country', 'foreign_worker_info_city',
#        'foreign_worker_info_education',
#        'foreign_worker_info_education_other', 'foreign_worker_info_inst',
#        'foreign_worker_info_major', 'foreign_worker_info_postal_code',
#        'foreign_worker_info_rel_occup_exp',
# ...

# %%
df['case_no']
# Out:
# 0         A-07323-97014
# 1         A-07332-99439
# 2         A-07333-99643
# 3         A-07339-01930
# 4         A-07345-03565
#               ...
# 374357              NaN
# 374358              NaN
# 374359              NaN
# 374360              NaN
# 374361              NaN
# Name: case_no, Length: 374362, dtype: object

# %%
df['case_number']
# Out:
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#               ...
# 374357    A-16363-85407
# 374358    A-16271-56745
# 374359    A-16354-82345
# 374360    A-16357-84250
# 374361    A-16279-59292
# Name: case_number, Length: 374362, dtype: object

# %%
#here i am going to drop one columns

# %%
df.drop("case_no",axis=1,inplace=True)

# %%
df.columns.values
# Out:
# array(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_number',
#        'case_received_date', 'case_status', 'class_of_admission',
#        'country_of_citizenship', 'country_of_citzenship', 'decision_date',
#        'employer_address_1', 'employer_address_2', 'employer_city',
#        'employer_country', 'employer_decl_info_title', 'employer_name',
#        'employer_num_employees', 'employer_phone', 'employer_phone_ext',
#        'employer_postal_code', 'employer_state', 'employer_yr_estab',
#        'foreign_worker_info_alt_edu_experience',
#        'foreign_worker_info_birth_country', 'foreign_worker_info_city',
#        'foreign_worker_info_education',
#        'foreign_worker_info_education_other', 'foreign_worker_info_inst',
#        'foreign_worker_info_major', 'foreign_worker_info_postal_code',
#        'foreign_worker_info_rel_occup_exp',
# ...

# %%
df['case_status']
# Out:
# 0         Certified
# 1            Denied
# 2         Certified
# 3         Certified
# 4         Certified
#             ...
# 374357    Withdrawn
# 374358    Withdrawn
# 374359    Withdrawn
# 374360    Withdrawn
# 374361    Withdrawn
# Name: case_status, Length: 374362, dtype: object

# %%
df.case_status
# Out:
# 0         Certified
# 1            Denied
# 2         Certified
# 3         Certified
# 4         Certified
#             ...
# 374357    Withdrawn
# 374358    Withdrawn
# 374359    Withdrawn
# 374360    Withdrawn
# 374361    Withdrawn
# Name: case_status, Length: 374362, dtype: object

# %%
df["case_status"]!="Withdrawn"# withdrawn application should not be analysed
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 374357    False
# 374358    False
# 374359    False
# 374360    False
# 374361    False
# Name: case_status, Length: 374362, dtype: bool

# %%
df=df[df["case_status"]!="Withdrawn"]

# %%
df
# Out:
#        add_these_pw_job_title_9089   agent_city  \
# 0                              NaN          NaN
# 1                              NaN          NaN
# 2                              NaN          NaN
# 3                              NaN          NaN
# 4                              NaN          NaN
# ...                            ...          ...
# 374349                         NaN   Cincinnati
# 374350                         NaN      Addison
# 374351                         NaN  Santa Clara
# 374352                         NaN     New York
# 374353                         NaN       Edison
#
#                                 agent_firm_name agent_state application_type  \
# 0                                           NaN         NaN             PERM
# 1                                           NaN         NaN             PERM
# 2                                           NaN         NaN             PERM
# ...

# %%
df.case_status
# Out:
# 0         Certified
# 1            Denied
# 2         Certified
# 3         Certified
# 4         Certified
#             ...
# 374349    Certified
# 374350    Certified
# 374351    Certified
# 374352    Certified
# 374353    Certified
# Name: case_status, Length: 356168, dtype: object

# %%
df.case_status.unique()
# Out:
# array(['Certified', 'Denied', 'Certified-Expired'], dtype=object)

# %%
#The code updates the 'case_status' column in a Pandas DataFrame (df)
# , changing any occurrence of 'Certified-Expired' to 'Certified'.
df.loc[df.case_status=='Certified-Expired','case_status']='Certified'

# %%
df.case_status.unique()
# Out:
# array(['Certified', 'Denied'], dtype=object)

# %%
df.case_status.value_counts()
# Out:
# case_status
# Certified    330519
# Denied        25649
# Name: count, dtype: int64

# %%
# What is insights of this dataset
# 7% people are denied

# %%
df.case_status.value_counts(normalize=True) # to know percentage
# Out:
# case_status
# Certified    0.927986
# Denied       0.072014
# Name: proportion, dtype: float64

# %%
# how to drop null value

# %%
df.dropna(axis=1,how='all',inplace=True)

# %%
df
# Out:
#        add_these_pw_job_title_9089   agent_city  \
# 0                              NaN          NaN
# 1                              NaN          NaN
# 2                              NaN          NaN
# 3                              NaN          NaN
# 4                              NaN          NaN
# ...                            ...          ...
# 374349                         NaN   Cincinnati
# 374350                         NaN      Addison
# 374351                         NaN  Santa Clara
# 374352                         NaN     New York
# 374353                         NaN       Edison
#
#                                 agent_firm_name agent_state application_type  \
# 0                                           NaN         NaN             PERM
# 1                                           NaN         NaN             PERM
# 2                                           NaN         NaN             PERM
# ...

# %%
df.dropna(axis=0,how='all',inplace=True)

# %%
df
# Out:
#        add_these_pw_job_title_9089   agent_city  \
# 0                              NaN          NaN
# 1                              NaN          NaN
# 2                              NaN          NaN
# 3                              NaN          NaN
# 4                              NaN          NaN
# ...                            ...          ...
# 374349                         NaN   Cincinnati
# 374350                         NaN      Addison
# 374351                         NaN  Santa Clara
# 374352                         NaN     New York
# 374353                         NaN       Edison
#
#                                 agent_firm_name agent_state application_type  \
# 0                                           NaN         NaN             PERM
# 1                                           NaN         NaN             PERM
# 2                                           NaN         NaN             PERM
# ...

# %%
df.columns
# Out:
# Index(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_number', 'case_received_date',
#        'case_status', 'class_of_admission', 'country_of_citizenship',
#        ...
#        'ri_pvt_employment_firm_to', 'ri_us_workers_considered',
#        'schd_a_sheepherder', 'us_economic_sector', 'wage_offer_from_9089',
#        'wage_offer_to_9089', 'wage_offer_unit_of_pay_9089',
#        'wage_offered_from_9089', 'wage_offered_to_9089',
#        'wage_offered_unit_of_pay_9089'],
#       dtype='object', length=153)

# %%
df.application_type
# Out:
# 0         PERM
# 1         PERM
# 2         PERM
# 3         PERM
# 4         PERM
#           ...
# 374349     NaN
# 374350     NaN
# 374351     NaN
# 374352     NaN
# 374353     NaN
# Name: application_type, Length: 356168, dtype: object

# %%
df['application_type'].value_counts().plot(kind='bar',color='red')
# Out:
# <Axes: xlabel='application_type'>

# %%
# most people online Apply

# %%
sns.countplot(data=df,x='application_type')
# Out:
# <Axes: xlabel='application_type', ylabel='count'>

# %%
df.columns
# Out:
# Index(['add_these_pw_job_title_9089', 'agent_city', 'agent_firm_name',
#        'agent_state', 'application_type', 'case_number', 'case_received_date',
#        'case_status', 'class_of_admission', 'country_of_citizenship',
#        ...
#        'ri_pvt_employment_firm_to', 'ri_us_workers_considered',
#        'schd_a_sheepherder', 'us_economic_sector', 'wage_offer_from_9089',
#        'wage_offer_to_9089', 'wage_offer_unit_of_pay_9089',
#        'wage_offered_from_9089', 'wage_offered_to_9089',
#        'wage_offered_unit_of_pay_9089'],
#       dtype='object', length=153)

# %%
df.us_economic_sector
# Out:
# 0                            IT
# 1         Other Economic Sector
# 2                     Aerospace
# 3         Other Economic Sector
# 4                  Advanced Mfg
#                   ...
# 374349                      NaN
# 374350                      NaN
# 374351                      NaN
# 374352                      NaN
# 374353                      NaN
# Name: us_economic_sector, Length: 356168, dtype: object

# %%
economic_sector=df['us_economic_sector'].value_counts()

# %%
economic_sector
# Out:
# us_economic_sector
# IT                       49311
# Advanced Mfg             17601
# Other Economic Sector    14662
# Finance                   8686
# Educational Services      8561
# Health Care               6407
# Retail                    4208
# Aerospace                 3917
# Hospitality               1767
# Construction              1315
# Automotive                1084
# Energy                    1021
# Transportation             893
# Agribusiness               784
# Biotechnology              436
# Geospatial                 137
# Homeland Security           78
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,12))
plt.pie(economic_sector,labels=economic_sector.index,autopct='%1.1f%%')
plt.show()

# %%
df
# Out:
#        add_these_pw_job_title_9089   agent_city  \
# 0                              NaN          NaN
# 1                              NaN          NaN
# 2                              NaN          NaN
# 3                              NaN          NaN
# 4                              NaN          NaN
# ...                            ...          ...
# 374349                         NaN   Cincinnati
# 374350                         NaN      Addison
# 374351                         NaN  Santa Clara
# 374352                         NaN     New York
# 374353                         NaN       Edison
#
#                                 agent_firm_name agent_state application_type  \
# 0                                           NaN         NaN             PERM
# 1                                           NaN         NaN             PERM
# 2                                           NaN         NaN             PERM
# ...

# %%
df['decision_date']
# Out:
# 0         2012-02-01
# 1         2011-12-21
# 2         2011-12-01
# 3         2011-12-01
# 4         2012-01-26
#              ...
# 374349    2016-12-30
# 374350    2016-12-30
# 374351    2016-12-30
# 374352    2016-12-30
# 374353    2016-12-30
# Name: decision_date, Length: 356168, dtype: object

# %%
df['decision_date']=pd.to_datetime(df['decision_date'])
df['year']=df['decision_date'].dt.year

# %%
df['year']
# Out:
# 0         2012
# 1         2011
# 2         2011
# 3         2011
# 4         2012
#           ...
# 374349    2016
# 374350    2016
# 374351    2016
# 374352    2016
# 374353    2016
# Name: year, Length: 356168, dtype: int32

# %%
fig, ax=plt.subplots(figsize=(12,12))
sns.countplot(x='year',hue='case_status',data=df)
ax.set(xlabel="Visa application year",ylabel="Number of applications")
plt.show()

# %%
# insight>> Increase visa count yearly
# or we can say that : as number of application is increasing 
# also number of certified and denied is Increase

# %%
fig, ax=plt.subplots(figsize=(12,12))
sns.countplot(x='employer_city',hue='year',data=df,order=df.employer_city.value_counts().iloc[:10].index)
ax.set(xlabel="employer_city",ylabel="Number of applications")
plt.xticks(rotation=90)
plt.show()
